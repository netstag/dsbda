# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("dataset_Facebook.csv" , sep=';')

# %%
df
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0              139441   Photo         2          12             4          3
# 1              139441  Status         2          12             3         10
# 2              139441   Photo         3          12             3          3
# 3              139441   Photo         2          12             2         10
# 4              139441   Photo         2          12             2          3
# ..                ...     ...       ...         ...           ...        ...
# 495             85093   Photo         3           1             7          2
# 496             81370   Photo         2           1             5          8
# 497             81370   Photo         1           1             5          2
# 498             81370   Photo         3           1             4         11
# 499             81370   Photo         2           1             4          4
#
# ...

# %%
df.columns
# Out:
# Index(['Page total likes', 'Type', 'Category', 'Post Month', 'Post Weekday',
#        'Post Hour', 'Paid', 'Lifetime Post Total Reach',
#        'Lifetime Post Total Impressions', 'Lifetime Engaged Users',
#        'Lifetime Post Consumers', 'Lifetime Post Consumptions',
#        'Lifetime Post Impressions by people who have liked your Page',
#        'Lifetime Post reach by people who like your Page',
#        'Lifetime People who have liked your Page and engaged with your post',
#        'comment', 'like', 'share', 'Total Interactions'],
#       dtype='object')

# %%
df['Type'].values
# Out:
# array(['Photo', 'Status', 'Photo', 'Photo', 'Photo', 'Status', 'Photo',
#        'Photo', 'Status', 'Photo', 'Status', 'Photo', 'Photo', 'Photo',
#        'Photo', 'Status', 'Photo', 'Photo', 'Status', 'Photo', 'Photo',
#        'Photo', 'Link', 'Photo', 'Status', 'Status', 'Status', 'Photo',
#        'Photo', 'Video', 'Photo', 'Photo', 'Photo', 'Photo', 'Photo',
#        'Photo', 'Photo', 'Photo', 'Status', 'Photo', 'Status', 'Link',
#        'Photo', 'Link', 'Photo', 'Link', 'Status', 'Link', 'Photo',
#        'Link', 'Photo', 'Photo', 'Photo', 'Photo', 'Photo', 'Video',
#        'Photo', 'Photo', 'Photo', 'Photo', 'Photo', 'Photo', 'Photo',
#        'Photo', 'Photo', 'Photo', 'Photo', 'Photo', 'Photo', 'Photo',
#        'Photo', 'Video', 'Status', 'Photo', 'Video', 'Photo', 'Photo',
#        'Photo', 'Photo', 'Photo', 'Status', 'Photo', 'Photo', 'Photo',
#        'Status', 'Photo', 'Link', 'Photo', 'Photo', 'Photo', 'Photo',
# ...

# %%
sub1 = df[df['Type']== 'Photo']

# %%
sub1
# Out:
#      Page total likes   Type  Category  Post Month  Post Weekday  Post Hour  \
# 0              139441  Photo         2          12             4          3
# 2              139441  Photo         3          12             3          3
# 3              139441  Photo         2          12             2         10
# 4              139441  Photo         2          12             2          3
# 6              139441  Photo         3          12             1          3
# ..                ...    ...       ...         ...           ...        ...
# 495             85093  Photo         3           1             7          2
# 496             81370  Photo         2           1             5          8
# 497             81370  Photo         1           1             5          2
# 498             81370  Photo         3           1             4         11
# 499             81370  Photo         2           1             4          4
#
# ...

# %%
sub1.shape
# Out:
# (426, 19)

# %%
sub2 = df[df['Type']== 'Status']
sub2
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 1              139441  Status         2          12             3         10
# 5              139441  Status         2          12             1          9
# 8              139441  Status         2          12             7          3
# 10             139441  Status         2          12             5         10
# 15             138414  Status         2          12             3         10
# 18             138414  Status         3          12             2          3
# 24             138414  Status         2          12             6         10
# 25             138458  Status         2          12             6          3
# 26             138458  Status         2          12             5         11
# 38             138895  Status         2          12             7          9
# 40             138895  Status         2          12             6         11
# ...

# %%
sub2.shape
# Out:
# (45, 19)

# %%
sub3 = df.iloc[0:100]
sub3
# Out:
#     Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0             139441   Photo         2          12             4          3
# 1             139441  Status         2          12             3         10
# 2             139441   Photo         3          12             3          3
# 3             139441   Photo         2          12             2         10
# 4             139441   Photo         2          12             2          3
# ..               ...     ...       ...         ...           ...        ...
# 95            137059   Photo         3          10             6         10
# 96            137059   Photo         1          10             6          3
# 97            137059   Photo         2          10             5         11
# 98            137020  Status         2          10             5          3
# 99            137020   Photo         1          10             4         10
#
# ...

# %%
sub3.shape
# Out:
# (100, 19)

# %%
sub4 = df.iloc[100 :]
sub4
# Out:
#      Page total likes   Type  Category  Post Month  Post Weekday  Post Hour  \
# 100            137020  Photo         1          10             4          9
# 101            137020  Photo         2          10             4          3
# 102            137020  Photo         3          10             3         10
# 103            137020  Photo         1          10             3          4
# 104            137020  Photo         1          10             2         11
# ..                ...    ...       ...         ...           ...        ...
# 495             85093  Photo         3           1             7          2
# 496             81370  Photo         2           1             5          8
# 497             81370  Photo         1           1             5          2
# 498             81370  Photo         3           1             4         11
# 499             81370  Photo         2           1             4          4
#
# ...

# %%
sub5 = df[['Page total likes', 'Type', 'Category', 'Post Month', 'Post Weekday','Post Hour', 'Paid']]
sub5
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0              139441   Photo         2          12             4          3
# 1              139441  Status         2          12             3         10
# 2              139441   Photo         3          12             3          3
# 3              139441   Photo         2          12             2         10
# 4              139441   Photo         2          12             2          3
# ..                ...     ...       ...         ...           ...        ...
# 495             85093   Photo         3           1             7          2
# 496             81370   Photo         2           1             5          8
# 497             81370   Photo         1           1             5          2
# 498             81370   Photo         3           1             4         11
# 499             81370   Photo         2           1             4          4
#
#      Paid
# 0     0.0
# 1     0.0
# ...

# %%
sub6 = df[['Post Hour', 'Paid', 'Lifetime Post Total Reach',
       'Lifetime Post Total Impressions', 'Lifetime Engaged Users',
       'Lifetime Post Consumers', 'Lifetime Post Consumptions',
       'Lifetime Post Impressions by people who have liked your Page',
       'Lifetime Post reach by people who like your Page',
       'Lifetime People who have liked your Page and engaged with your post',
       'comment', 'like', 'share', 'Total Interactions']]
sub6
# Out:
#      Post Hour  Paid  Lifetime Post Total Reach  \
# 0            3   0.0                       2752
# 1           10   0.0                      10460
# 2            3   0.0                       2413
# 3           10   1.0                      50128
# 4            3   0.0                       7244
# ..         ...   ...                        ...
# 495          2   0.0                       4684
# 496          8   0.0                       3480
# 497          2   0.0                       3778
# 498         11   0.0                       4156
# 499          4   NaN                       4188
#
#      Lifetime Post Total Impressions  Lifetime Engaged Users  \
# 0                               5091                     178
# 1                              19057                    1457
# 2                               4373                     177
# 3                              87991                    2211
# 4                              13594                     671
# ...

# %%
sub7 = df[['like', 'share', 'Total Interactions']]
sub7
# Out:
#        like  share  Total Interactions
# 0      79.0   17.0                 100
# 1     130.0   29.0                 164
# 2      66.0   14.0                  80
# 3    1572.0  147.0                1777
# 4     325.0   49.0                 393
# ..      ...    ...                 ...
# 495    53.0   26.0                  84
# 496    53.0   22.0                  75
# 497    93.0   18.0                 115
# 498    91.0   38.0                 136
# 499    91.0   28.0                 119
#
# [500 rows x 3 columns]

# %%
sub1.shape
# Out:
# (426, 19)

# %%
sub2.shape
# Out:
# (45, 19)

# %%
merge1 = pd.concat([sub1 , sub2]) #row
merge1
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0              139441   Photo         2          12             4          3
# 2              139441   Photo         3          12             3          3
# 3              139441   Photo         2          12             2         10
# 4              139441   Photo         2          12             2          3
# 6              139441   Photo         3          12             1          3
# ..                ...     ...       ...         ...           ...        ...
# 334            119198  Status         2           5             1          2
# 352            116435  Status         1           5             4          3
# 362            116091  Status         2           5             5          7
# 371            113028  Status         2           4             6          3
# 416            104070  Status         1           3             3         15
#
# ...

# %%
sub3.shape
# Out:
# (100, 19)

# %%
sub4.shape
# Out:
# (400, 19)

# %%
merge2 = pd.concat([sub3 , sub4]) #roww
merge2
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0              139441   Photo         2          12             4          3
# 1              139441  Status         2          12             3         10
# 2              139441   Photo         3          12             3          3
# 3              139441   Photo         2          12             2         10
# 4              139441   Photo         2          12             2          3
# ..                ...     ...       ...         ...           ...        ...
# 495             85093   Photo         3           1             7          2
# 496             81370   Photo         2           1             5          8
# 497             81370   Photo         1           1             5          2
# 498             81370   Photo         3           1             4         11
# 499             81370   Photo         2           1             4          4
#
# ...

# %%
merge2.shape
# Out:
# (500, 19)

# %%
sub5.shape
# Out:
# (500, 7)

# %%
sub6.shape
# Out:
# (500, 14)

# %%
merge3 = pd.concat([sub5 , sub6] , axis = 1) #column
merge3
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0              139441   Photo         2          12             4          3
# 1              139441  Status         2          12             3         10
# 2              139441   Photo         3          12             3          3
# 3              139441   Photo         2          12             2         10
# 4              139441   Photo         2          12             2          3
# ..                ...     ...       ...         ...           ...        ...
# 495             85093   Photo         3           1             7          2
# 496             81370   Photo         2           1             5          8
# 497             81370   Photo         1           1             5          2
# 498             81370   Photo         3           1             4         11
# 499             81370   Photo         2           1             4          4
#
# ...

# %%
merge3.shape
# Out:
# (500, 21)

# %%
#sort

# %%
df.sort_values(by=['Category'])
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 497             81370   Photo         1           1             5          2
# 17             138414   Photo         1          12             2         12
# 21             138414   Photo         1          12             7         10
# 22             138414    Link         1          12             7         10
# 29             138895   Video         1          12             4         11
# ..                ...     ...       ...         ...           ...        ...
# 18             138414  Status         3          12             2          3
# 498             81370   Photo         3           1             4         11
# 493             85093   Photo         3           1             1          2
# 494             85093   Photo         3           1             7         10
# 495             85093   Photo         3           1             7          2
#
# ...

# %%
df.sort_values(by=['Type'])
# Out:
#      Page total likes   Type  Category  Post Month  Post Weekday  Post Hour  \
# 438             98195   Link         2           3             6          6
# 470             91437   Link         1           2             3         13
# 41             138895   Link         1          12             6          3
# 43             138353   Link         1          12             5          3
# 45             138353   Link         1          12             4          3
# ..                ...    ...       ...         ...           ...        ...
# 71             137893  Video         1          11             5          3
# 55             138329  Video         1          11             6          2
# 277            126424  Video         1           6             2         13
# 243            130791  Video         1           7             3         11
# 74             137893  Video         1          11             3         11
#
# ...

# %%
df_copy = pd.DataFrame(data=df)

# %%
df.columns
# Out:
# Index(['Page total likes', 'Type', 'Category', 'Post Month', 'Post Weekday',
#        'Post Hour', 'Paid', 'Lifetime Post Total Reach',
#        'Lifetime Post Total Impressions', 'Lifetime Engaged Users',
#        'Lifetime Post Consumers', 'Lifetime Post Consumptions',
#        'Lifetime Post Impressions by people who have liked your Page',
#        'Lifetime Post reach by people who like your Page',
#        'Lifetime People who have liked your Page and engaged with your post',
#        'comment', 'like', 'share', 'Total Interactions'],
#       dtype='object')

# %%
df_transposed = df_copy.transpose()
df_transposed
# Out:
#                                                        0       1       2    \
# Page total likes                                    139441  139441  139441
# Type                                                 Photo  Status   Photo
# Category                                                 2       2       3
# Post Month                                              12      12      12
# Post Weekday                                             4       3       3
# Post Hour                                                3      10       3
# Paid                                                   0.0     0.0     0.0
# Lifetime Post Total Reach                             2752   10460    2413
# Lifetime Post Total Impressions                       5091   19057    4373
# Lifetime Engaged Users                                 178    1457     177
# Lifetime Post Consumers                                109    1361     113
# ...

# %%
#pivot table

# %%
table = pd.pivot_table(data = df , values = ['Lifetime Post Total Impressions', 'Lifetime Engaged Users'] , index=['Type'])

# %%
table
# Out:
#         Lifetime Engaged Users  Lifetime Post Total Impressions
# Type
# Link                342.818182                     28725.454545
# Photo               818.946009                     28994.497653
# Status             2040.222222                     24244.466667
# Video              1707.000000                    102622.428571

# %%
df.isnull().sum()
# Out:
# Page total likes                                                       0
# Type                                                                   0
# Category                                                               0
# Post Month                                                             0
# Post Weekday                                                           0
# Post Hour                                                              0
# Paid                                                                   1
# Lifetime Post Total Reach                                              0
# Lifetime Post Total Impressions                                        0
# Lifetime Engaged Users                                                 0
# Lifetime Post Consumers                                                0
# Lifetime Post Consumptions                                             0
# Lifetime Post Impressions by people who have liked your Page           0
# ...

# %%
df.dtypes
# Out:
# Page total likes                                                         int64
# Type                                                                    object
# Category                                                                 int64
# Post Month                                                               int64
# Post Weekday                                                             int64
# Post Hour                                                                int64
# Paid                                                                   float64
# Lifetime Post Total Reach                                                int64
# Lifetime Post Total Impressions                                          int64
# Lifetime Engaged Users                                                   int64
# Lifetime Post Consumers                                                  int64
# Lifetime Post Consumptions                                               int64
# ...

# %%
df.columns
# Out:
# Index(['Page total likes', 'Type', 'Category', 'Post Month', 'Post Weekday',
#        'Post Hour', 'Paid', 'Lifetime Post Total Reach',
#        'Lifetime Post Total Impressions', 'Lifetime Engaged Users',
#        'Lifetime Post Consumers', 'Lifetime Post Consumptions',
#        'Lifetime Post Impressions by people who have liked your Page',
#        'Lifetime Post reach by people who like your Page',
#        'Lifetime People who have liked your Page and engaged with your post',
#        'comment', 'like', 'share', 'Total Interactions'],
#       dtype='object')

# %%
mean_paid = df['Paid'].mean()
mean_paid
# Out:
# np.float64(0.2785571142284569)

# %%
df['Paid'] = df['Paid'].fillna(mean_paid)

# %%
df['Paid'].isnull().sum()
# Out:
# np.int64(0)

# %%
mean_like = df['like'].mean()
mean_like
# Out:
# np.float64(177.94589178356713)

# %%
df['like'] = df['like'].fillna(mean_like)

# %%
df['like'].isnull().sum()
# Out:
# np.int64(0)

# %%
#reshape 
numeric_data = df[["Page total likes", "Post Month", "Post Hour"]].head(6).values
print("Original shape:", numeric_data.shape)

reshaped_data = numeric_data.reshape(3, 6)
print("Reshaped to (3, 6):", reshaped_data.shape)
print(reshaped_data)
# Out:
# Original shape: (6, 3)
# Reshaped to (3, 6): (3, 6)
# [[139441     12      3 139441     12     10]
#  [139441     12      3 139441     12     10]
#  [139441     12      3 139441     12      9]]
